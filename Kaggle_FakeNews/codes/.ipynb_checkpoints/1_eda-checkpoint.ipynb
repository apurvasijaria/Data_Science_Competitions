# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import re, os, string

# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
## Loading cleaned data
train = pd.read_csv('../dataset/train_cleaned.csv')
test = pd.read_csv('../dataset/test_cleaned.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20800 non-null  int64
#  1   title           20242 non-null  object
#  2   author          18841 non-null  object
#  3   text            20761 non-null  object
#  4   label           20800 non-null  int64
#  5   original_text   20761 non-null  object
#  6   text_words      20800 non-null  object
#  7   text_digit_cnt  20800 non-null  int64
#  8   clean_text_lem  20800 non-null  object
#  9   clean_text      20800 non-null  object
#  10  title_polarity  20800 non-null  float64
#  11  text_polarity   20800 non-null  float64
#  12  ttl_wrds        20800 non-null  int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 2.1+ MB

# %%
train.describe()
##notihng captured in title polarity
# Out:
#                  id         label  text_digit_cnt  title_polarity  \
# count  20800.000000  20800.000000    20800.000000         20800.0
# mean   10399.500000      0.500625        9.056058             0.0
# std     6004.587135      0.500012       13.538005             0.0
# min        0.000000      0.000000        0.000000             0.0
# 25%     5199.750000      0.000000        2.000000             0.0
# 50%    10399.500000      1.000000        5.000000             0.0
# 75%    15599.250000      1.000000       12.000000             0.0
# max    20799.000000      1.000000      470.000000             0.0
#
#        text_polarity      ttl_wrds
# count   20800.000000  20800.000000
# mean        0.058661    785.088029
# std         0.105855    898.795776
# min        -1.000000      0.000000
# 25%         0.002688    278.000000
# 50%         0.054762    576.000000
# 75%         0.107318   1087.000000
# max         1.000000  24870.000000

# %%
test.describe()
##notihng captured in title polarity
# Out:
#                  id  text_digit_cnt  title_polarity  text_polarity  \
# count   5200.000000     5200.000000          5200.0    5200.000000
# mean   23399.500000        9.292500             0.0       0.060311
# std     1501.255031       13.877532             0.0       0.107129
# min    20800.000000        0.000000             0.0      -1.000000
# 25%    22099.750000        2.000000             0.0       0.006126
# 50%    23399.500000        6.000000             0.0       0.056517
# 75%    24699.250000       12.000000             0.0       0.107307
# max    25999.000000      430.000000             0.0       0.925000
#
#            ttl_wrds
# count   5200.000000
# mean     799.990577
# std      873.774152
# min        0.000000
# 25%      290.000000
# 50%      591.000000
# 75%     1121.000000
# max    18934.000000

# %%
## Replacing null string in NaN, to treat them as string not float
train = train.replace(np.nan, '', regex=True)
test = test.replace(np.nan, '', regex=True)

# %% [markdown]
# ## Analyzing Patterns and Structure of Data

# %%
## Checking Author column
train[train['author'].map(len) > 25].author.value_counts()
# Out:
# noreplybloggercom alexander light                 80
# noreplybloggercom der postillon                   64
# andrea kannapell and sandra stevenson             57
# dikran arakelian noreplybloggercom                51
# jafe arnoldski noreplybloggercom                  44
#                                                   ..
# mikkael a sekeres md and timothy d gilligan md     1
# jim rutenberg emily steel and john koblin          1
# julie creswell and mary williams walsh             1
# ashley southall and sean piccoli                   1
# katie rogers and elisabetta povoledo               1
# Name: author, Length: 1253, dtype: int64

# %%
## Checking more frequent authors names and sources
import collections

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

elements_count = collections.Counter(' '.join(train.author).split())
elements_count = sortFreqDict(elements_count)

# %%
elements_count
# Out:
# [(1545, 'and'),
#  (493, 'michael'),
#  (425, 'the'),
#  (406, 'john'),
#  (352, 'breitbart'),
#  (318, 'noreplybloggercom'),
#  (269, 'daniel'),
#  (269, 'charlie'),
#  (269, 'admin'),
#  (258, 'david'),
#  (256, 'pam'),
#  (243, 'key'),
#  (215, 'news'),
#  (210, 'd'),
#  (196, 'ian'),
#  (183, 'ben'),
#  (173, 'mike'),
#  (172, 'hudson'),
#  (171, 'jerome'),
#  (168, 'baker'),
#  (164, 'patrick'),
#  (164, 'james'),
#  (160, 'robert'),
#  (159, 'j'),
#  (158, 'andrew'),
#  (157, 'eric'),
#  (154, 'neil'),
#  (149, 'author'),
#  (147, 'jason'),
#  (147, 'b'),
#  (147, 'alan'),
#  (145, 'thomas'),
#  (142, 'hayward'),
#  (142, 'alexander'),
#  (141, 'stevenson'),
#  (141, 'spiering'),
#  (141, 'maggie'),
#  (140, 'haberman'),
#  (136, 'w'),
#  (134, 'adam'),
#  (132, 'anonymous'),
#  (130, 'e'),
#  (129, 'sandra'),
#  (129, 'katherine'),
#  (124, 'todd'),
#  (124, 'rodriguez'),
#  (124, 'richard'),
#  (124, 'dr'),
#  (124, 'bob'),
#  (124, 'alex'),
#  (122, 'warner'),
#  (122, 'huston'),
#  (121, 'smith'),
#  (120, 'times'),
#  (120, 'dan'),
#  (120, 'amy'),
#  (119, 'hanchett'),
#  (119, 'dave'),
#  (116, 'nussbaum'),
#  (116, 'karen'),
#  (115, 'katie'),
#  (114, 'jeff'),
#  (113, 'matt'),
#  (111, 'mark'),
#  (111, 'joel'),
#  (108, 'jack'),
#  (107, 'poor'),
#  (107, 'pollak'),
#  (107, 'julie'),
#  (107, 'hawkins'),
#  (107, 'awr'),
#  (106, 'tom'),
#  (106, 'nicholas'),
#  (105, 'jonathan'),
#  (102, 'trent'),
#  (102, 'matthew'),
#  (102, 'editor'),
#  (102, 'eddy'),
#  (100, 'staff'),
#  (100, 'aaron'),
#  (97, 'london'),
#  (96, 'scott'),
#  (96, 'price'),
#  (95, 'chris'),
#  (94, 'christopher'),
#  (92, 'williams'),
#  (91, 'jennifer'),
#  (90, 'kew'),
#  (89, 'nash'),
#  (88, 'henry'),
#  (87, 'lucas'),
#  (86, 'pakalert'),
#  (85, 's'),
#  (85, 'lavine'),
#  (85, 'doc'),
#  (84, 'starkman'),
#  (84, 'amanda'),
#  (83, 'shear'),
#  (83, 'liam'),
#  (83, 'davis'),
#  (82, 'light'),
#  (82, 'gillian'),
#  (82, 'ansary'),
#  (81, 'post'),
#  (81, 'frances'),
#  (80, 'peter'),
#  (80, 'nolan'),
#  (80, 'charles'),
#  (79, 'susan'),
#  (79, 'nate'),
#  (79, 'martin'),
#  (78, 'paul'),
#  (78, 'no'),
#  (77, 'joe'),
#  (77, 'hodges'),
#  (77, 'activist'),
#  (76, 'nick'),
#  (76, 'm'),
#  (76, 'binder'),
#  (76, 'a'),
#  (75, 'steve'),
#  (75, 'jerusalem'),
#  (75, 'iwb'),
#  (74, 'union'),
#  (74, 'sean'),
#  (74, 'european'),
#  (74, 'barenakedislam'),
#  (73, 'michelle'),
#  (73, 'klein'),
#  (72, 'r'),
#  (72, 'hirschfeld'),
#  (72, 'ditz'),
#  (72, 'andrea'),
#  (70, 'victor'),
#  (69, 'parker'),
#  (69, 'kannapell'),
#  (69, 'edjenner'),
#  (68, 'tim'),
#  (68, 'starr'),
#  (67, 'wolff'),
#  (67, 'phd'),
#  (67, 'penny'),
#  (66, 'world'),
#  (66, 'stockman'),
#  (66, 'slavo'),
#  (66, 'sheik'),
#  (66, 'mac'),
#  (66, 'iron'),
#  (65, 'stegall'),
#  (65, 'rachel'),
#  (65, 'kaitlyn'),
#  (65, 'healy'),
#  (65, 'ciccotta'),
#  (64, 'postillon'),
#  (64, 'martel'),
#  (64, 'lee'),
#  (64, 'landler'),
#  (64, 'der'),
#  (64, 'burns'),
#  (64, 'berry'),
#  (63, 'uid'),
#  (63, 'king'),
#  (63, 'heather'),
#  (62, 'callaghan'),
#  (61, 'rosenberg'),
#  (61, 'rappeport'),
#  (61, 'mele'),
#  (61, 'grider'),
#  (61, 'geoffrey'),
#  (61, 'blinder'),
#  (59, 'flegenheimer'),
#  (58, 'william'),
#  (58, 'shorty'),
#  (58, 'sanger'),
#  (58, 'consortiumnewscom'),
#  (56, 'munro'),
#  (55, 'saker'),
#  (55, 'riehl'),
#  (55, 'jim'),
#  (55, 'jeremy'),
#  (53, 'zraick'),
#  (53, 'rt'),
#  (53, 'chozick'),
#  (52, 'ryan'),
#  (52, 'guest'),
#  (52, 'daily'),
#  (51, 'wmwadmin'),
#  (51, 'steinhauer'),
#  (51, 'emily'),
#  (51, 'dikran'),
#  (51, 'c'),
#  (51, 'arakelian'),
#  (50, 'nazarian'),
#  (50, 'mcphate'),
#  (50, 'jon'),
#  (50, 'coward'),
#  (50, 'adelle'),
#  (49, 'wong'),
#  (49, 'stack'),
#  (49, 'jonah'),
#  (49, 'hale'),
#  (49, 'de'),
#  (48, 'virginia'),
#  (48, 'sarah'),
#  (48, 'new'),
#  (48, 'moreno'),
#  (48, 'mchugh'),
#  (48, 'howard'),
#  (48, 'gwinn'),
#  (48, 'dylan'),
#  (47, 'greenfield'),
#  (47, 'conservative'),
#  (47, 'christine'),
#  (47, 'brandon'),
#  (47, 'anglin'),
#  (46, 'writer'),
#  (46, 'steven'),
#  (46, 'savage'),
#  (46, 'g'),
#  (46, 'bromwich'),
#  (45, 'tomlinson'),
#  (45, 'stevew'),
#  (45, 'rebecca'),
#  (45, 'liptak'),
#  (45, 'dyer'),
#  (44, 'rick'),
#  (44, 'portnoy'),
#  (44, 'jafe'),
#  (44, 'goldman'),
#  (44, 'engel'),
#  (44, 'craig'),
#  (44, 'arnoldski'),
#  (43, 'schmidt'),
#  (43, 'brooks'),
#  (42, 'ron'),
#  (42, 'pérezpeña'),
#  (42, 'pcr'),
#  (42, 'moons'),
#  (42, 'barbaro'),
#  (41, 'york'),
#  (41, 'sam'),
#  (41, 'peters'),
#  (41, 'montgomery'),
#  (41, 'monteverde'),
#  (41, 'kevin'),
#  (41, 'f'),
#  (41, 'buckley'),
#  (41, 'arnold'),
#  (40, 'tech'),
#  (40, 'stephen'),
#  (40, 'rogers'),
#  (40, 'rivero'),
#  (40, 'lipton'),
#  (40, 'kristina'),
#  (40, 'church'),
#  (40, 'beforeitsnewscom'),
#  (40, 'barnes'),
#  (40, 'ashley'),
#  (40, 'arango'),
#  (40, 'anne'),
#  (39, 'schmitt'),
#  (39, 'millennial'),
#  (39, 'ken'),
#  (39, 'julius'),
#  (39, 'hubris'),
#  (39, 'hauser'),
#  (39, 'barnard'),
#  (39, 'alexandra'),
#  (38, 'poke'),
#  (38, 'marc'),
#  (38, 'madeline'),
#  (38, 'jr'),
#  (38, 'joseph'),
#  (38, 'gordon'),
#  (38, 'easley'),
#  (38, 'crouse'),
#  (38, 'carl'),
#  (37, 'sanghun'),
#  (37, 'niraj'),
#  (37, 'liz'),
#  (37, 'lisa'),
#  (37, 'jane'),
#  (37, 'grynbaum'),
#  (37, 'chokshi'),
#  (37, 'choe'),
#  (37, 'benjamin'),
#  (36, 'rich'),
#  (36, 'ortiz'),
#  (36, 'mcdermid'),
#  (36, 'mason'),
#  (36, 'lichtblau'),
#  (36, 'ildefonso'),
#  (36, 'deborah'),
#  (36, 'cooper'),
#  (36, 'brian'),
#  (35, 'roberts'),
#  (35, 'mccabe'),
#  (35, 'johnson'),
#  (34, 'yamiche'),
#  (34, 'taylor'),
#  (34, 'simon'),
#  (34, 'marlow'),
#  (34, 'edwin'),
#  (34, 'deacon'),
#  (34, 'boyle'),
#  (34, 'alcindor'),
#  (33, '–'),
#  (33, 'truth'),
#  (33, 'stern'),
#  (33, 'quest'),
#  (33, 'network'),
#  (33, 'moran'),
#  (33, 'mora'),
#  (33, 'isaac'),
#  (33, 'grant'),
#  (33, 'barry'),
#  (32, 'mitch'),
#  (32, 'miller'),
#  (32, 'goldstein'),
#  (32, 'fausset'),
#  (32, 'danan'),
#  (32, 'corasaniti'),
#  (32, 'carney'),
#  (32, 'broadcast'),
#  (31, 'irwin'),
#  (31, 'friedman'),
#  (31, 'delingpole'),
#  (31, 'contributing'),
#  (31, 'bill'),
#  (30, 'yves'),
#  (30, 'street'),
#  (30, 'slattery'),
#  (30, 'sausage'),
#  (30, 'pear'),
#  (30, 'oliver'),
#  (30, 'machine'),
#  (30, 'jameson'),
#  (30, 'erlanger'),
#  (30, 'binyamin'),
#  (30, 'appelbaum'),
#  (29, 'workman'),
#  (29, 'rutenberg'),
#  (29, 'ruiz'),
#  (29, 'froelich'),
#  (29, 'ann'),
#  (29, 'ali'),
#  (28, 'tracy'),
#  (28, 'rodgers'),
#  (28, 'p'),
#  (28, 'la'),
#  (28, 'koblin'),
#  (28, 'colin'),
#  (28, 'chriss'),
#  (28, 'bell'),
#  (28, 'arnaldo'),
#  (27, 'walsh'),
#  (27, 'wakingtimes'),
#  (27, 'tyler'),
#  (27, 'sydney'),
#  (27, 'somini'),
#  (27, 'shea'),
#  (27, 'sengupta'),
#  (27, 'porter'),
#  (27, 'lane'),
#  (27, 'jj'),
#  (27, 'gerry'),
#  (27, 'fisher'),
#  (27, 'fandos'),
#  (27, 'ember'),
#  (27, 'danny'),
#  (27, 'dailouk'),
#  (27, 'casey'),
#  (27, 'brianna'),
#  (27, 'acuesta'),
#  (26, 'to'),
#  (26, 'shaw'),
#  (26, 'schwartz'),
#  (26, 'orissa'),
#  (26, 'mather'),
#  (26, 'leahy'),
#  (26, 'kershner'),
#  (26, 'kaplan'),
#  (26, 'isabel'),
#  (26, 'harris'),
#  (26, 'glenn'),
#  (26, 'eli'),
#  (26, 'edmondo'),
#  (26, 'doug'),
#  (26, 'corbett'),
#  (26, 'clark'),
#  (26, 'burr'),
#  (26, 'amp'),
#  (25, 'vanessa'),
#  (25, 'tv'),
#  (25, 'tass'),
#  (25, 'stephanie'),
#  (25, 'rubin'),
#  (25, 'press'),
#  (25, 'perlez'),
#  (25, 'of'),
#  (25, 'natalie'),
#  (25, 'melissa'),
#  (25, 'luther'),
#  (25, 'kesel'),
#  (25, 'kenneth'),
#  (25, 'kate'),
#  (25, 'k'),
#  (25, 'eder'),
#  (25, 'daisy'),
#  (25, 'ce'),
#  (25, 'brown'),
#  (25, 'adltabatabai'),
#  (24, 'washingtonsblog'),
#  (24, 'shane'),
#  (24, 'sewell'),
#  (24, 'max'),
#  (24, 'kirk'),
#  (24, 'huetteman'),
#  (24, 'hubbard'),
#  (24, 'hiroko'),
#  (24, 'goodman'),
#  (24, 'gladstone'),
#  (24, 'emmarie'),
#  (24, 'donna'),
#  (24, 'cohn'),
#  (24, 'claire'),
#  (24, 'chan'),
#  (24, 'castle'),
#  (24, 'campbell'),
#  (23, 'x'),
#  (23, 'v'),
#  (23, 'tabuchi'),
#  (23, 'swanson'),
#  (23, 'stolberg'),
#  (23, 'sheryl'),
#  (23, 'mujib'),
#  (23, 'mashal'),
#  (23, 'l'),
#  (23, 'kim'),
#  (23, 'justin'),
#  (23, 'jones'),
#  (23, 'jess'),
#  (23, 'itzkoff'),
#  (23, 'glen'),
#  (23, 'gay'),
#  (23, 'frank'),
#  (23, 'davenport'),
#  (23, 'darby'),
#  (23, 'confessore'),
#  (23, 'chen'),
#  (23, 'chang'),
#  (23, 'bidgood'),
#  (22, 'waked'),
#  (22, 'tfpp'),
#  (22, 'schuttler'),
#  (22, 'romero'),
#  (22, 'merced'),
#  (22, 'margaret'),
#  (22, 'lance'),
#  (22, 'ford'),
#  (22, 'edmunds'),
#  (22, 'coral'),
#  (22, 'apuzzo'),
#  (21, 'wolf'),
#  (21, 'whitney'),
#  (21, 'snyder'),
#  (21, 'reed'),
#  (21, 'redacción'),
#  (21, 'realdeal'),
#  (21, 'otis'),
#  (21, 'mcbride'),
#  (21, 'hqanon'),
#  (21, 'hess'),
#  (21, 'edward'),
#  (21, 'declan'),
#  (21, 'coulter'),
#  (21, 'cohen'),
#  (21, 'chronicles'),
#  (21, 'cartel'),
#  (21, 'alissa'),
#  (20, 'webb'),
#  (20, 'watson'),
#  (20, 'vnn'),
#  (20, 'tomás'),
#  (20, 'sheeple'),
#  (20, 'rowan'),
#  (20, 'poniewozik'),
#  (20, 'paulson'),
#  (20, 'palmer'),
#  (20, 'morris'),
#  (20, 'kimiko'),
#  (20, 'julia'),
#  (20, 'je'),
#  (20, 'helene'),
#  (20, 'fuentes'),
#  (20, 'freytastamura'),
#  (20, 'elizabeth'),
#  (20, 'bilefsky'),
#  (20, 'banister'),
#  (20, 'ariana'),
#  (19, 'zuesse'),
#  (19, 'thrush'),
#  (19, 't'),
#  (19, 'st'),
#  (19, 'spayd'),
#  (19, 'saavedra'),
#  (19, 'patricia'),
#  (19, 'paddock'),
#  (19, 'macfarquhar'),
#  (19, 'longman'),
#  (19, 'krieger'),
#  (19, 'klukowski'),
#  (19, 'jeré'),
#  (19, 'higgins'),
#  (19, 'hallett'),
#  (19, 'gardiner'),
#  (19, 'feuer'),
#  (19, 'coscarelli'),
#  (19, 'caramanica'),
#  (19, 'cara'),
#  (19, 'benner'),
#  (18, 'wesley'),
#  (18, 'voltairenetorg'),
#  (18, 'tony'),
#  (18, 'stewart'),
#  (18, 'stacy'),
#  (18, 'senior'),
#  (18, 'sailer'),
#  (18, 'rod'),
#  (18, 'nwo'),
#  (18, 'noah'),
#  (18, 'monica'),
#  (18, 'merrill'),
#  (18, 'jenna'),
#  (18, 'hulse'),
#  (18, 'horowitz'),
#  (18, 'hoffman'),
#  (18, 'gosztola'),
#  (18, 'gehl'),
#  (18, 'gabriel'),
#  (18, 'fleur'),
#  (18, 'carol'),
#  (18, 'anna'),
#  (18, 'alison'),
#  (17, 'русском'),
#  (17, 'на'),
#  (17, 'yeginsu'),
#  (17, 'williamson'),
#  (17, 'vora'),
#  (17, 'tokyowashi'),
#  (17, 'tavernise'),
#  (17, 'steel'),
#  (17, 'shivani'),
#  (17, 'santora'),
#  (17, 'sangerkatz'),
#  (17, 'sabrina'),
#  (17, 'ross'),
#  (17, 'robertson'),
#  (17, 'rbth'),
#  (17, 'pareles'),
#  (17, 'newsguy'),
#  (17, 'nelson'),
#  (17, 'md'),
#  (17, 'mazzetti'),
#  (17, 'margot'),
#  (17, 'kumar'),
#  (17, 'kramer'),
#  (17, 'kike'),
#  (17, 'jeffrey'),
#  (17, 'hatr'),
#  (17, 'geeta'),
#  (17, 'free'),
#  (17, 'fountain'),
#  (17, 'flynn'),
#  (17, 'durden'),
#  (17, 'colm'),
#  (17, 'christina'),
#  (17, 'ceylan'),
#  (17, 'cacciola'),
#  (17, 'brett'),
#  (17, 'bokhari'),
#  (17, 'anand'),
#  (17, 'alter'),
#  (17, 'allum'),
#  (17, 'adl'),
#  (17, 'abrams'),
#  (16, 'zernike'),
#  (16, 'zach'),
#  (16, 'waldstein'),
#  (16, 'smale'),
#  (16, 'robles'),
#  (16, 'nixon'),
#  (16, 'maslin'),
#  (16, 'kolata'),
#  (16, 'kang'),
#  (16, 'is'),
#  (16, 'informationclearinghouseinfo'),
#  (16, 'hadfield'),
#  (16, 'gpd'),
#  (16, 'gina'),
#  (16, 'george'),
#  (16, 'garcía'),
#  (16, 'ewing'),
#  (16, 'erik'),
#  (16, 'editorial'),
#  (16, 'debbie'),
#  (16, 'davey'),
#  (16, 'cowley'),
#  (16, 'azam'),
#  (16, 'austen'),
#  (16, 'associated'),
#  (16, 'ahmed'),
#  (16, 'adler'),
#  (16, 'abelson'),
#  (15, 'victoria'),
#  (15, 'trip'),
#  (15, 'strether'),
#  (15, 'schuessler'),
#  (15, 'saxena'),
#  (15, 'on'),
#  (15, 'ok'),
#  (15, 'o'),
#  (15, 'nordland'),
#  (15, 'nicole'),
#  (15, 'nagourney'),
#  (15, 'mind'),
#  (15, 'menon'),
#  (15, 'mcadams'),
#  (15, 'marquis'),
#  (15, 'lizette'),
#  (15, 'lambert'),
#  (15, 'jacobs'),
#  (15, 'hugh'),
#  (15, 'hope'),
#  (15, 'gettleman'),
#  (15, 'fairbanks'),
#  (15, 'erdbrink'),
#  (15, 'dmitry'),
#  (15, 'cassandra'),
#  (15, 'breeden'),
#  (15, 'boehler'),
#  (15, 'bernish'),
#  (15, 'becker'),
#  (15, 'aurelien'),
#  (15, 'alvarez'),
#  (15, 'abby'),
#  (14, 'with'),
#  (14, 'wingfield'),
#  (14, 'what'),
#  (14, 'weiser'),
#  (14, 'thought'),
#  (14, 'that'),
#  (14, 'saad'),
#  (14, 'robin'),
#  (14, 'project'),
#  (14, 'povoledo'),
#  (14, 'pamela'),
#  (14, 'nir'),
#  (14, 'neal'),
#  (14, 'mr'),
#  (14, 'manohla'),
#  (14, 'mahler'),
#  (14, 'kit'),
#  (14, 'jay'),
#  (14, 'in'),
#  (14, 'iaboni'),
#  (14, 'hwaida'),
#  (14, 'graham'),
#  (14, 'grady'),
#  (14, 'fitzsimmons'),
#  (14, 'evolution'),
#  (14, 'elisabetta'),
#  (14, 'elisabeth'),
#  (14, 'dickinson'),
#  (14, 'dennis'),
#  (14, 'denise'),
#  (14, 'dargis'),
#  (14, 'collective'),
#  (14, 'cecilia'),
#  (14, 'catherine'),
#  (14, 'baxter'),
#  (14, 'anthony'),
#  (14, 'adelmann'),
#  (13, 'wright'),
#  (13, 'wines'),
#  (13, 'wells'),
#  (13, 'walker'),
#  (13, 'unleashed'),
#  (13, 'turbeville'),
#  (13, 'timothy'),
#  (13, 'susanne'),
#  (13, 'sorkin'),
#  (13, 'semple'),
#  (13, 'russell'),
#  (13, 'rory'),
#  (13, 'richardson'),
#  (13, 'remy'),
#  (13, 'pianigiani'),
#  (13, 'pete'),
#  (13, 'newman'),
#  (13, 'megan'),
#  (13, 'louis'),
#  (13, 'leslie'),
#  (13, 'leigh'),
#  (13, 'kyle'),
#  (13, 'kincaid'),
#  (13, 'kanter'),
#  (13, 'joanna'),
#  (13, 'h'),
#  (13, 'gretchen'),
#  (13, 'goodnough'),
#  (13, 'gaia'),
#  (13, 'emma'),
#  (13, 'ellen'),
#  (13, 'derbyshire'),
#  (13, 'cliff'),
#  (13, 'bruce'),
#  (13, 'bowley'),
#  (13, 'belson'),
#  (13, 'al'),
#  (12, 'winter'),
#  (12, 'wilmot'),
#  (12, 'vincent'),
#  (12, 'team'),
#  (12, 'sisario'),
#  (12, 'shadwick'),
#  (12, 'seth'),
#  (12, 'searcey'),
#  (12, 'rojas'),
#  (12, 'robbins'),
#  (12, 'proviso'),
#  (12, 'philip'),
#  (12, 'para'),
#  (12, 'medina'),
#  (12, 'mcneil'),
#  (12, 'manny'),
#  (12, 'malkin'),
#  (12, 'lieber'),
#  (12, 'lana'),
#  (12, 'jacob'),
#  (12, 'ives'),
#  (12, 'hrafnkell'),
#  (12, 'haraldsson'),
#  (12, 'grimes'),
#  (12, 'green'),
#  (12, 'fernandez'),
#  (12, 'español'),
#  (12, 'en'),
#  (12, 'eduardo'),
#  (12, 'dsg'),
#  (12, 'donald'),
#  (12, 'donadio'),
#  (12, 'dionne'),
#  (12, 'davidswanson'),
#  (12, 'corkery'),
#  (12, 'corey'),
#  (12, 'clarey'),
#  (12, 'chaos'),
#  (12, 'caitlin'),
#  (12, 'boudette'),
#  (12, 'annie'),
#  (11, 'your'),
#  (11, 'vivian'),
#  (11, 'virgil'),
#  (11, 'vindu'),
#  (11, 'valizadeh'),
#  (11, 'stranahan'),
#  (11, 'south'),
#  (11, 'sarich'),
#  (11, 'sack'),
#  (11, 'roosh'),
#  (11, 'red'),
#  (11, 'pogrebin'),
#  (11, 'philipps'),
#  (11, 'overbye'),
#  (11, 'nossiter'),
#  (11, 'mcgeehan'),
#  (11, 'mcfadden'),
#  (11, 'manjoo'),
#  (11, 'macur'),
#  (11, 'lyons'),
#  (11, 'landon'),
#  (11, 'juliet'),
#  (11, 'iii'),
#  (11, 'group'),
#  (11, 'greger'),
#  (11, 'gold'),
#  (11, 'goel'),
#  (11, 'front'),
#  (11, 'forsythe'),
#  (11, 'flying'),
#  (11, 'farhad'),
#  (11, 'duff'),
#  (11, 'donnelly'),
#  (11, 'diserio'),
#  (11, 'dickerson'),
#  (11, 'cockburn'),
#  (11, 'carroll'),
#  (11, 'carey'),
#  (11, 'brenda'),
#  (11, 'brantley'),
#  (11, 'bradford'),
#  (11, 'bosman'),
#  (11, 'assemblyman'),
#  (11, 'ap'),
#  (11, 'alexis'),
#  (10, 'zero'),
#  (10, 'yee'),
#  (10, 'xavi'),
#  (10, 'will'),
#  (10, 'white'),
#  (10, 'villamor'),
#  (10, 'up'),
#  (10, 'twohey'),
#  (10, 'turkewitz'),
#  (10, 'this'),
#  (10, 'taub'),
#  (10, 'tatiana'),
#  (10, 'tablefan'),
#  (10, 'streitfeld'),
#  (10, 'sifton'),
#  (10, 'shattuck'),
#  (10, 'selwyn'),
#  (10, 'santos'),
#  (10, 'saint'),
#  (10, 'reynolds'),
#  (10, 'raphael'),
#  (10, 'puig'),
#  (10, 'protess'),
#  (10, 'preston'),
#  (10, 'picker'),
#  (10, 'perlroth'),
#  (10, 'pennington'),
#  (10, 'patriotrising'),
#  (10, 'murphy'),
#  (10, 'moore'),
#  (10, 'mm'),
#  (10, 'mitchell'),
#  (10, 'minder'),
#  (10, 'media'),
#  (10, 'lucus'),
#  (10, 'lendman'),
#  (10, 'keith'),
#  (10, 'kathryn'),
#  (10, 'ivan'),
#  (10, 'innis'),
#  (10, 'hill'),
#  (10, 'hedge'),
#  (10, 'hassan'),
#  (10, 'hamlin'),
#  (10, 'haiphong'),
#  (10, 'greenhalgh'),
#  (10, 'garner'),
#  (10, 'from'),
#  (10, 'foderaro'),
#  (10, 'fernanda'),
#  (10, 'felipe'),
#  (10, 'fed'),
#  (10, 'faclm'),
#  (10, 'egner'),
#  (10, 'eckholm'),
#  (10, 'dwight'),
#  (10, 'duke'),
#  (10, 'dubenko'),
#  (10, 'darrell'),
#  (10, 'dane'),
#  (10, 'caryn'),
#  (10, 'cain'),
#  (10, 'belluck'),
#  (10, 'barber'),
#  (10, 'april'),
#  (9, 'you'),
#  (9, 'wilson'),
#  (9, 'wendal'),
#  (9, 'vlasic'),
#  (9, 'tancredo'),
#  (9, 'swoyer'),
#  (9, 'strom'),
#  (9, 'shepard'),
#  (9, 'sapna'),
#  (9, 'rashbaum'),
#  (9, 'randy'),
#  (9, 'ramos'),
#  (9, 'pollack'),
#  (9, 'pat'),
#  (9, 'nathaniel'),
#  (9, 'motoko'),
#  (9, 'michiko'),
#  (9, 'manlio'),
#  (9, 'maheshwari'),
#  (9, 'lyall'),
#  (9, 'letsbereal'),
#  (9, 'lela'),
#  (9, 'laurie'),
#  (9, 'larry'),
#  (9, 'krauss'),
#  (9, 'kilgannon'),
#  (9, 'kent'),
#  (9, 'kennedy'),
#  (9, 'kakutani'),
#  (9, 'javi'),
#  (9, 'inessa'),
#  (9, 'ice'),
#  (9, 'herszenhorn'),
#  (9, 'harry'),
#  (9, 'hari'),
#  (9, 'hadid'),
#  (9, 'goodstein'),
#  (9, 'gilad'),
#  (9, 'fuller'),
#  (9, 'fulford'),
#  (9, 'fisk'),
#  (9, 'eligon'),
#  (9, 'drew'),
#  (9, 'dozois'),
#  (9, 'dom'),
#  (9, 'dixon'),
#  (9, 'dinucci'),
#  (9, 'diaa'),
#  (9, 'conor'),
#  (9, 'clifford'),
#  (9, 'branch'),
#  (9, 'bradsher'),
#  (9, 'atzmon'),
#  (9, 'ambellas'),
#  (9, 'allison'),
#  (9, 'ahtribunecom'),
#  (9, 'adams'),
#  (8, 'zinoman'),
#  (8, 'zimmer'),
#  (8, 'weiland'),
#  (8, 'they'),
#  (8, 'syrmopoulos'),
#  (8, 'stanley'),
#  (8, 'sopan'),
#  (8, 'sheri'),
#  (8, 'sharon'),
#  (8, 'serge'),
#  (8, 'scofield'),
#  (8, 'schwirtz'),
#  (8, 'schlossberg'),
#  (8, 'rukmini'),
#  (8, 'roni'),
#  (8, 'risen'),
#  (8, 'remnick'),
#  (8, 'real'),
#  (8, 'ramzy'),
#  (8, 'rabin'),
#  (8, 'powell'),
#  (8, 'popper'),
#  (8, 'paton'),
#  (8, 'omar'),
#  (8, 'nechepurenko'),
#  (8, 'myers'),
#  (8, 'mozur'),
#  (8, 'menahan'),
#  (8, 'martino'),
#  (8, 'lyman'),
#  (8, 'levin'),
#  (8, 'kingsley'),
#  (8, 'kayla'),
#  (8, 'katz'),
#  (8, 'katrin'),
#  (8, 'josh'),
#  (8, 'jerrilynn'),
#  (8, 'jd'),
#  (8, 'javier'),
#  (8, 'jan'),
#  (8, 'jackson'),
#  (8, 'infowarscom'),
#  (8, 'hurt'),
#  (8, 'huff'),
#  (8, 'house'),
#  (8, 'hornberger'),
#  (8, 'heyes'),
#  (8, 'hernández'),
#  (8, 'herman'),
#  (8, 'gorman'),
#  (8, 'goodrich'),
#  (8, 'genzlinger'),
#  (8, 'gelles'),
#  (8, 'fink'),
#  (8, 'farah'),
#  (8, 'ethan'),
#  (8, 'eowyn'),
#  (8, 'dwyer'),
#  (8, 'dulis'),
#  (8, 'deb'),
#  (8, 'dawn'),
#  (8, 'common'),
#  (8, 'colarossi'),
#  (8, 'callimachi'),
#  (8, 'byas'),
#  (8, 'buchanan'),
#  (8, 'bryan'),
#  (8, 'bennhold'),
#  (8, 'baroud'),
#  (8, 'bailey'),
#  (8, 'bagli'),
#  (8, 'antiwarcom'),
#  ...]

# %%
elements_count = collections.Counter(' '.join(test.author).split())
elements_count = sortFreqDict(elements_count)
elements_count
## top authors are similar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-500bede742b1> in <module>
# ----> 1 elements_count = collections.Counter(' '.join(test.author).split())
#       2 elements_count = sortFreqDict(elements_count)
#       3 elements_count
#       4 ## top authors are similar
#
# NameError: name 'collections' is not defined

# %%
## Getting column names
cols = train.columns

# %% [markdown]
# ## Visualizing data and Correlations

# %%
# %matplotlib inline
train.hist(bins=50, figsize = (20,15))
plt.show()

# %% [markdown]
# #### Removing Columns based on data visualization
#
# title_polarity has 0 variance and contributes nothing in the model

# %%
train.drop(['title_polarity','id'],axis=1,inplace= True)

# %%
test_id = test.id
test.drop(['title_polarity','id'],axis=1,inplace= True)

# %%
## Getting column names 

# All column names
cols = train.columns

# only numnerical columns
cols_num = train.select_dtypes([np.number]).columns

# only string columns
cols_str = train.select_dtypes(object).columns

print(cols)
print(cols_num)
print(cols_str)
# Out:
# Index(['title', 'author', 'text', 'label', 'original_text', 'text_words',
#        'text_digit_cnt', 'clean_text_lem', 'clean_text', 'text_polarity',
#        'ttl_wrds'],
#       dtype='object')
# Index(['label', 'text_digit_cnt', 'text_polarity', 'ttl_wrds'], dtype='object')
# Index(['title', 'author', 'text', 'original_text', 'text_words',
#        'clean_text_lem', 'clean_text'],
#       dtype='object')

# %%
## Analyzing new variables distribution w.r.t. to the label varaible
print(pd.pivot_table(train, index = 'label', values = cols_num[1:],aggfunc = 'sum'))
print(pd.pivot_table(train, index = 'label', values = cols_num[1:],aggfunc = 'min'))
print(pd.pivot_table(train, index = 'label', values = cols_num[1:],aggfunc = 'max'))
print(pd.pivot_table(train, index = 'label', values = cols_num[1:],aggfunc = np.mean))
# Out:
#        text_digit_cnt  text_polarity  ttl_wrds
# label
# 0              108444     631.065967   9522464
# 1               79922     589.091514   6807367
#        text_digit_cnt  text_polarity  ttl_wrds
# label
# 0                   0          -0.45         1
# 1                   0          -1.00         0
#        text_digit_cnt  text_polarity  ttl_wrds
# label
# 0                 235           0.65     15349
# 1                 470           1.00     24870
#        text_digit_cnt  text_polarity    ttl_wrds
# label
# 0           10.440358       0.060755  916.767498
# 1            7.675214       0.056573  653.737348

# %% [markdown]
# #### On average fake news articles have less data citations, range to extreme polarity, and are shorter than real news
#
# This confirms the hypothesis about opinions.
#
# ## Correlations

# %%
cmap = sb.diverging_palette(220, 10, as_cmap=True)
sb.heatmap(train[cols_num].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# all three variables have some negative correlation with the label

# %%
## Visualizing variance of these variables with label
for col in cols_num[1:]:
    print(col)
    plt.scatter(train.label,train[col])
    plt.show()
# Out:
# text_digit_cnt
# text_polarity
# ttl_wrds

# %%
## text polarity and ttl_wrds have small positive correlation, check their distribution
plt.scatter(train.text_polarity,train.ttl_wrds)
